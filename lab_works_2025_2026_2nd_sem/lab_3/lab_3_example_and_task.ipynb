# %% [markdown]
# # Instruction the lab-work #3
# `TODO`: make the final .ipynb file in format `"{second_name}_{first_name}_{group_id}__lab_3.ipynb"`
#
# First name     - Volodymyr
#
# Second name    - Donets
#
# Group          - KU-31

# %% [markdown]
# # Task description
#
# ## Overall description
#
# In this work you'll try to build Conv ANN from scratch for image classification (or any other problem like regression?) for this you can use either provided dataset, either manually gathered (cats Vs dogs, tumors, plants diseases and so on).
# The second part of work you'll consider transfer learning (retraining previously state-of-art model with slight changes in it's architecture).
#
# BONUS TASK: trying model's explainability for explaining predictors by your ANN's.
#
# ## *Instructions for the work*
#
# 1. Select a dataset you interested in (do its preparation, like reshaping, making it grayscale etc.)
# 2. Carefully look at examples.
# 3. Develop your own architecture of Conv ANN model specific to your problem and try to modify it (add more layers, or more filters, or various filters size, etc).
# 4. Produce 3-4 models with various configurations.
# 5. Make conclusions on its performance.
# 6. In the second part of the work you'll try to reuse large computer vision model (like VGG-16, VGG-24, Inception, ResNet, and others) which were trained on the wide scope data (like classifying 1000 classes). Basically you'll do `Transfer Learning` technique.
# 7. Compare performance of your own models and build by Transfer Learning.
# 8. Make conclusions
# 9. **BONUS TASK**: use `SHAP`, `Saliency Maps` or any other method you'll find to highlight the important places on the image that it presents a specific regions made (or didn't make) influence on the model's specific decision (look at the single examples).
#
# ## Examples
# 1. Training tiny conv model [GitHub Jupyter Notebook0](https://github.com/VolDonets/machine_vision_projects_studing/blob/main/cifar_10_training/high_accuracy_cifar10.ipynb)
# 2. Transfer learning examples [GitHub Folder](https://github.com/VolDonets/machine_vision_projects_studing/tree/main/transfer_learning)
#
# ## Important
#
# 1. Do NOT solve the problem in a single cell, such work will be worth 0. If you struggle with Jupyter Notebook just ask for help teacher or your friends. Also, you can solve the lab work in .py files, but provide your report with in .pdf file in the similar format.
# 2. Do NOT try to steal others works. This year I'll try to consider this. And identical works will be worth 0 too.
# 3. You can (and probably should) solve the task of the lab work in the separate .ipynb file. Just take this file, clear my solution and replace it with your own.
# 4. Do NOT forget to leave CONCLUSIONS.
#
# ## How to get max num of points without personal work presentation.
#
# As I told you, you can get the maximum mark for all lab works without personal presentation in case of using something different and additional depth of work.
# So for this work you can:
#
# 1. Compare your results with other ANN models architecture like classical fully-connected ANN.
# 2. Perform data augmentation (read about it before), and compare model's results/robustness with/without data augmentation.
# 3. Apply various regularization's like L1/L2 add to Loss, Dropout, BatchNorm, etc.
# 4. Do BONUS task.

# %% [markdown]
# # Data for experiments (You can choose provided or manually collected)
#
# 0. Manually collect data, it could be anything (gestures, plants, mushrooms, animals, diseases, military stuff (like mine detection, etc).
# 1. [Caltech101 (101 classes classification)](https://www.tensorflow.org/datasets/catalog/caltech101)
# 2. [cars196 (196 classes of cars)](https://www.tensorflow.org/datasets/catalog/cars196)
# 3. [Cassava (1 healthy and 4 diseases of plants)](https://www.tensorflow.org/datasets/catalog/cassava)
# 4. [Cats Vs Dots](https://www.tensorflow.org/datasets/catalog/cats_vs_dogs)
# 5. [CheXpert is a large dataset of chest X-rays (14 classes)](https://www.tensorflow.org/datasets/catalog/chexpert)
# 6. [citrus_leaves (healthy & unhealthy citrus fruits & leaves)](https://www.tensorflow.org/datasets/catalog/citrus_leaves)
# 7. [Classification of textures in colorectal cancer histology](https://www.tensorflow.org/datasets/catalog/colorectal_histology)
# 8. [Brest Cancer](https://www.tensorflow.org/datasets/catalog/curated_breast_imaging_ddsm)
# 9. [The DeepWeeds dataset consists of 17,509 images capturing eight different weed species native to Australia](https://www.tensorflow.org/datasets/catalog/deep_weeds)
# 10. [diabetic_retinopathy_detection](https://www.tensorflow.org/datasets/catalog/diabetic_retinopathy_detection)
# 11. [The Dmlab dataset contains frames observed by the agent acting in the DeepMind Lab environment, which are annotated by the distance between the agent and various objects present in the environment.](https://www.tensorflow.org/datasets/catalog/dmlab)
# 12. [EuroSAT dataset is based on Sentinel-2 satellite images covering 13 spectral bands and consisting of 10 classes with 27000 labeled and geo-referenced samples.](https://www.tensorflow.org/datasets/catalog/eurosat)
# 13. [horses_or_humans](https://www.tensorflow.org/datasets/catalog/horses_or_humans)
# 14. [imagenet_sketch](https://www.tensorflow.org/datasets/catalog/imagenet_sketch)
# 15. [The Stanford Dogs dataset contains images of 120 breeds of dogs from around the world.](https://www.tensorflow.org/datasets/catalog/stanford_dogs)

# %% [markdown]
# # Install & import dependencies

# %% [markdown]
# # Utils

# %% [markdown]
# # Data Load & Prepare

# %% [markdown]
# # Experiments with the Conv ANN from scratch

# %% [markdown]
# # Experiments with Transfer Learning
