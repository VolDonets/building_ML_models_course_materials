# %% [markdown]
# # Instruction the lab-work #5
# `TODO`: make the final .ipynb file in format `"{second_name}_{first_name}_{group_id}__lab_5.ipynb"`
#
# First name     - Volodymyr
#
# Second name    - Donets
#
# Group          - KU-31

# %% [markdown]
# # Task description
#
# In this lab work you'll get familiar with various generative ANN model, primarily for image generation.
# The core task would be just run the code and conduct a few generations.
#
# ## Overall description
#
# ### I. Working with autoencoder model
#
# 1. Example located in the `example/autoenc__img_from_lat_space.ipynb`
# 2. Try to run the code with another images dataset (it could be a dataset from your previous lab, or could be something like Fashion MNIST). I recommend you to rescale the images (28x28, 32x32, or 64x64 max would be the best architecture in this case), and try to work with grayscale only.
# 3. On the trained model visualize your latent space.
# 4. Using randomly generated latent space try to generate images.
#
# ### II. Working with GAN / DeepConv GAN
#
# 1. Examples located in the `example/gan_mnist.ipynb` -- naive GAN (and it was successful), `example/dcgan_fashion_mnist_v1.ipynb` and `example/dcgan_fashion_mnist.ipynb` -- DeepConv GAN, it wasn't successful.
# 2. Try to train a GAN model with your own data (as it used in the previous part).
# 3. *BONUS*: figure out how to fix unsuccessful DCGAN models.
#
# ### III. Working with diffusion models
#
# 1. Examples located in `example/denoising_diffusion_probabilistic_model.ipynb` -- for the simplest Diffusion model (you can run it locally).
# 2. Examples located in `example/diffusion_model.ipynb` -- for the stable diffusion model with generating according to your prompt (you can run it locally if you have enough RAM (16Gb should be enough).
# 3. Just run a few experiments. What happens if you denoise denoised already image (do experiment with denoising_diffusion_p... )?
#
# ### IV. Using pretrained model for style transfer
#
# 1. Example located in `example/neural_style_transfer.ipynb`.
# 2. Non-mandatory: make code great again (make the code working with the modern Tensorflow lib, it previously worked with Python 3.9 and quite old Tensorflow)
#
# ## Important
#
# 1. **No Single-Cell Solutions**: Do NOT write all your code in a single Jupyter Notebook cell. Your code must be logically separated. Single-cell notebooks will receive a grade of 0. If you need help structuring a notebook, ask the instructor or your peers. Alternatively, you may submit well-structured .py files alongside a .pdf report of your results.
# 2. **Academic Integrity**: Plagiarism is prohibited. Identical or copied works will automatically receive a grade of 0.
# 3. **Submission Format**: You are encouraged to solve this assignment in a separate .ipynb file. You may duplicate the provided template, clear the existing solution, and build your own.
# 4. **Mandatory Conclusions**: A project without a written analytical conclusion is incomplete. Do not forget to summarize your findings at the end of your notebook.
#
# ## How to get max num of points without personal work presentation.
#
# As I told you, you can get the maximum mark for all lab works without personal presentation in case of using something different and additional depth of work.
# So for this work you can:
#
# 1. Do experiments, and add explanations and conclusions.
# 2. Don't forget to leave conclusions.
